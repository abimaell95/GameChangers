# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import multiprocessing
import numpy as np
import random as rd

# %%
path1 = "/content/drive/MyDrive/Datathon2022/data/olist_customers_dataset.csv"
path2 = "/content/drive/MyDrive/Datathon2022/data/olist_geolocation_dataset.csv"
path3 = "/content/drive/MyDrive/Datathon2022/data/olist_order_items_dataset.csv"
path4 = "/content/drive/MyDrive/Datathon2022/data/olist_order_payments_dataset.csv"
path5 = "/content/drive/MyDrive/Datathon2022/data/olist_order_reviews_dataset.csv"
path6 = "/content/drive/MyDrive/Datathon2022/data/olist_orders_dataset.csv"
path7 = "/content/drive/MyDrive/Datathon2022/data/olist_products_dataset.csv"
path8 = "/content/drive/MyDrive/Datathon2022/data/olist_sellers_dataset.csv"
path9 = "/content/drive/MyDrive/Datathon2022/data/product_category_name_translation.csv"

# %%
df1 = pd.read_csv(path1)
df2 = pd.read_csv(path2)
df3 = pd.read_csv(path3)
df4 = pd.read_csv(path4)
df5 = pd.read_csv(path5)
df6 = pd.read_csv(path6)
df7 = pd.read_csv(path7)
df8 = pd.read_csv(path8)
df9 = pd.read_csv(path9)

# %%
df6[["order_id", "customer_id"]]
# Out:
#                                order_id                       customer_id
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# [99441 rows x 2 columns]

# %%
df5[["order_id", "review_score"]]
# Out:
#                                order_id  review_score
# 0      73fc7af87114b39712e6da79b0a377eb             4
# 1      a548910a1c6147796b98fdf73dbeba33             5
# 2      f9e4b658b201a9f2ecdecbb34bed034b             5
# 3      658677c97b385a9be170737859d3511b             5
# 4      8e6bfb81e283fa7e4f11123a3fb894f1             5
# ...                                 ...           ...
# 99219  2a8c23fee101d4d5662fa670396eb8da             5
# 99220  22ec9f0669f784db00fa86d035cf8602             5
# 99221  55d4004744368f5571d1f590031933e4             5
# 99222  7725825d039fc1f0ceb7635e3f7d9206             4
# 99223  90531360ecb1eec2a1fbb265a0db0508             1
#
# [99224 rows x 2 columns]

# %%
df1[["customer_id", "customer_city"]]
# Out:
#                             customer_id          customer_city
# 0      06b8999e2fba1a1fbc88172c00ba8bc7                 franca
# 1      18955e83d337fd6b2def6b18a428ac77  sao bernardo do campo
# 2      4e7b3e00288586ebd08712fdd0374a03              sao paulo
# 3      b2b6027bc5c5109e529d4dc6358b12c3        mogi das cruzes
# 4      4f2d8ab171c80ec8364f7c12e35b23ad               campinas
# ...                                 ...                    ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f              sao paulo
# 99437  e7b71a9017aa05c9a7fd292d714858e8        taboao da serra
# 99438  5e28dfe12db7fb50a4b2f691faecea5e              fortaleza
# 99439  56b18e2166679b8a959d72dd06da27f9                 canoas
# 99440  274fa6071e5e17fe303b9748641082c8                  cotia
#
# [99441 rows x 2 columns]

# %%
dfUnion1=pd.merge(df1, df6, on='customer_id')
dfUnion1
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state  \
# ...

# %%
myDf=pd.merge(dfUnion1, df5, on='order_id')
dateExtract=myDf[["review_score", "customer_state"]]
myDf
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99219  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99220  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99221  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99222  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99223  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state  \
# ...

# %%
plt.figure(figsize=(20,20))
sns.barplot(y='customer_state',x='review_score', hue='customer_state',data=dateExtract)
